# %%
#FINANCIAL ANALYSIS OF GLOBAL BANKS' STOCK PRICES
from pandas_datareader import data,wb
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
start=datetime.datetime(2006,1,1)
end=datetime.datetime(2016,1,1)

# %%
BAC=data.DataReader('BAC','yahoo','2006')

# %%
BAC
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.942661
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.582188
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.625435
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.574959
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.596596
# ...               ...        ...        ...        ...         ...        ...
# 2022-01-12  49.380001  48.680000  49.169998  48.860001  41378000.0  48.860001
# 2022-01-13  49.490002  48.630001  48.919998  48.759998  46337500.0  48.759998
# 2022-01-14  48.230000  47.189999  47.520000  47.910000  72940500.0  47.910000
# 2022-01-18  47.919998  46.049999  47.849998  46.259998  65877400.0  46.259998
# 2022-01-19  48.580002  46.349998  48.389999  46.439999  84333600.0  46.439999
#
# [4040 rows x 6 columns]

# %%
BAC.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.942661
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.582188
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.625435
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.574959
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.596596

# %%
#citigroup bank
C=data.DataReader('C','yahoo',start,end)
#Goldman Sachs
GS=data.DataReader('GS','yahoo',start,end)
#JP Morgan
JPM=data.DataReader('JPM','yahoo',start,end)
#Morgan Stanley
MS=data.DataReader('MS','yahoo',start,end)

# %%
tickers=['BAC','C','GS','JPM','MS']

# %%
#concatenation
bank_stocks=pd.concat([BAC,C,GS,JPM,MS],axis=1,keys=tickers)
bank_stocks.head()
# Out:
#                   BAC                                                          \
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2006-01-03  47.180000  46.150002  46.919998  47.080002  16296700.0  33.942661
# 2006-01-04  47.240002  46.450001  47.000000  46.580002  17757900.0  33.582188
# 2006-01-05  46.830002  46.320000  46.580002  46.639999  14970700.0  33.625435
# 2006-01-06  46.910000  46.349998  46.799999  46.570000  12599800.0  33.574959
# 2006-01-09  46.970001  46.360001  46.720001  46.599998  15619400.0  33.596596
#
#                      C                                      ...        JPM  \
#                   High         Low        Open       Close  ...       Open
# Date                                                        ...
# 2006-01-03  493.799988  481.100006  490.000000  492.899994  ...  39.830002
# 2006-01-04  491.000000  483.500000  488.600006  483.799988  ...  39.779999
# ...

# %%
bank_stocks.columns
# Out:
# MultiIndex([('BAC',      'High'),
#             ('BAC',       'Low'),
#             ('BAC',      'Open'),
#             ('BAC',     'Close'),
#             ('BAC',    'Volume'),
#             ('BAC', 'Adj Close'),
#             (  'C',      'High'),
#             (  'C',       'Low'),
#             (  'C',      'Open'),
#             (  'C',     'Close'),
#             (  'C',    'Volume'),
#             (  'C', 'Adj Close'),
#             ( 'GS',      'High'),
#             ( 'GS',       'Low'),
#             ( 'GS',      'Open'),
#             ( 'GS',     'Close'),
#             ( 'GS',    'Volume'),
#             ( 'GS', 'Adj Close'),
#             ('JPM',      'High'),
#             ('JPM',       'Low'),
#             ('JPM',      'Open'),
#             ('JPM',     'Close'),
#             ('JPM',    'Volume'),
#             ('JPM', 'Adj Close'),
#             ( 'MS',      'High'),
#             ( 'MS',       'Low'),
#             ( 'MS',      'Open'),
# ...

# %%
bank_stocks.columns.names=['Bank Ticker','Stock Info']

# %%
bank_stocks.head(2)
# Out:
# Bank Ticker        BAC                                               \
# Stock Info        High        Low       Open      Close      Volume
# Date
# 2006-01-03   47.180000  46.150002  46.919998  47.080002  16296700.0
# 2006-01-04   47.240002  46.450001  47.000000  46.580002  17757900.0
#
# Bank Ticker                      C                                      ...  \
# Stock Info   Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2006-01-03   33.942661  493.799988  481.100006  490.000000  492.899994  ...
# 2006-01-04   33.582188  491.000000  483.500000  488.600006  483.799988  ...
#
# Bank Ticker        JPM                                           MS  \
# Stock Info        Open      Close      Volume  Adj Close       High
# Date
# 2006-01-03   39.830002  40.189999  12838600.0  26.345469  58.490002
# 2006-01-04   39.779999  39.619999  13491500.0  26.193419  59.279999
#
# Bank Ticker
# ...

# %%
bank_stocks['BAC']['Close'].max()
# Out:
# 54.900001525878906

# %%
for i in tickers:
    print("Bank=",i,";",bank_stocks[i]['Close'].max())
# Out:
# Bank= BAC ; 54.900001525878906
# Bank= C ; 564.0999755859375
# Bank= GS ; 247.9199981689453
# Bank= JPM ; 70.08000183105469
# Bank= MS ; 89.30000305175781

# %%
#cross section
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.900002
# C      564.099976
# GS     247.919998
# JPM     70.080002
# MS      89.300003
# dtype: float64

# %%
#to see how the returns are moving
#returns=(Value at time_t-value at time_(t-1))/(value at time_(t-1))
returns=pd.DataFrame()

# %%
for i in tickers:
    returns[i+'return']=bank_stocks[i]['Close'].pct_change()

# %%
returns
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586
# ...               ...       ...       ...        ...       ...
# 2022-01-12  -0.007112  0.000000  0.000000   0.000000  0.000000
# 2022-01-13  -0.002047  0.000000  0.000000   0.000000  0.000000
# 2022-01-14  -0.017432  0.000000  0.000000   0.000000  0.000000
# 2022-01-18  -0.034440  0.000000  0.000000   0.000000  0.000000
# 2022-01-19   0.003891  0.000000  0.000000   0.000000  0.000000
#
# [4040 rows x 5 columns]

# %%
returns['BACreturn'].min()
# Out:
# -0.2896935896149381

# %%
returns['BACreturn'].idxmin()
# Out:
# Timestamp('2009-01-20 00:00:00')

# %%
returns['BACreturn'].max()
# Out:
# 0.35269125610998264

# %%
returns['BACreturn'].idxmax()
# Out:
# Timestamp('2009-04-09 00:00:00')

# %%
returns.idxmin()
# Out:
# BACreturn   2009-01-20
# Creturn     2009-02-27
# GSreturn    2009-01-20
# JPMreturn   2009-01-20
# MSreturn    2008-10-09
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# BACreturn   2009-04-09
# Creturn     2008-11-24
# GSreturn    2008-11-24
# JPMreturn   2009-01-21
# MSreturn    2008-10-13
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# BACreturn    0.031693
# Creturn      0.030520
# GSreturn     0.020039
# JPMreturn    0.021837
# MSreturn     0.029848
# dtype: float64

# %%
returns.std().idxmax()
# Out:
# 'BACreturn'

# %%
returns.loc['2005-01-01':'2015-12-31'].std().idxmax()
# Out:
# 'Creturn'

# %%
y=returns.loc['2005-01-01':'2015-12-31']
y.head()
# Out:
#             BACreturn   Creturn  GSreturn  JPMreturn  MSreturn
# Date
# 2006-01-03        NaN       NaN       NaN        NaN       NaN
# 2006-01-04  -0.010620 -0.018462 -0.013812  -0.014183  0.000686
# 2006-01-05   0.001288  0.004961 -0.000393   0.003029  0.002742
# 2006-01-06  -0.001501  0.000000  0.014169   0.007046  0.001025
# 2006-01-09   0.000644 -0.004731  0.012030   0.016242  0.010586

# %%
#DATA VISUALIZATION
sns.displot(y['MSreturn'],kde=True,bins=25)

# %%
z=returns.loc['2008-01-01':'2008-12-31']

# %%
sns.displot(z['Creturn'],kde=True,bins=10)

# %%
#INTERACTIVE PLOTTING
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
for i in tickers:
    bank_stocks[i]['Close'].plot(label=i)

# %%
for i in tickers:
    bank_stocks[i]['Close'].plot(label=i,figsize=(12,6))
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').iplot()
# Out:
# <div>                            <div id="f18f0348-7da8-4110-b585-868fecdf5424" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
#MOVING AVERAGES
plt.figure(figsize=(12,4))
BAC['Close'].loc['2008-01-01':'2008-12-31'].rolling(window=30).mean().plot(label='30 day MA')
BAC['Close'].loc['2008-01-01':'2008-12-31'].plot(label='BAC Close Price')
plt.legend()

# %%
bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr() #correlation
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS
# Bank Ticker
# BAC          1.000000  0.971516  0.550898  0.103874  0.944218
# C            0.971516  1.000000  0.434123  0.003515  0.933609
# GS           0.550898  0.434123  1.000000  0.685286  0.683792
# JPM          0.103874  0.003515  0.685286  1.000000  0.250427
# MS           0.944218  0.933609  0.683792  0.250427  1.000000

# %%
#HEATMAP
sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
close_c=bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr()

# %%
close_c
# Out:
# Bank Ticker       BAC         C        GS       JPM        MS
# Bank Ticker
# BAC          1.000000  0.971516  0.550898  0.103874  0.944218
# C            0.971516  1.000000  0.434123  0.003515  0.933609
# GS           0.550898  0.434123  1.000000  0.685286  0.683792
# JPM          0.103874  0.003515  0.685286  1.000000  0.250427
# MS           0.944218  0.933609  0.683792  0.250427  1.000000

# %%
close_c.iplot(kind='heatmap',colorscale='rdylbu')
# Out:
# <div>                            <div id="e52cb6d8-8541-49a8-a4d9-c531c18fd7ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
bac2015=BAC[['Open','High','Low','Close']].loc['2015-01-01':'2015-12-31']
bac2015.iplot(kind='candle')
# Out:
# <div>                            <div id="7148374a-4e8c-4828-b2b1-0c2032d0ef9f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
